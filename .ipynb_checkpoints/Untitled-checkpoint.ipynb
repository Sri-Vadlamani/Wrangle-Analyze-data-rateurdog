# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
import tweepy 
import json
import os
import time
from datetime import datetime
import seaborn as sns
from pprint import pprint

# %%
json_data=open('github-users-stats.json',"rb")
data = json.load(json_data, encoding="utf8")
print data['email']
pprint(data)
json_data.close()
# Out:
# {'0xced': {'aka': 'Cédric Luthi',
#            'contributions': 187,
#            'email': 'cedric.luthi@gmail.com',
#            'followers': 259,
#            'gravatar': 'https://secure.gravatar.com/avatar/e634e02646d909ce006da694a9deec28?s=140&amp;d=https://a248.e.akamai.net/assets.github.com%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#            'language': 'Objective-C',
#            'location': 'Geneva, Switzerland',
#            'repositories': 67,
#            'username': '0xced'},
#  '3rd-Eden': {'aka': 'Arnout Kazemier',
#               'contributions': 841,
#               'email': '',
#               'followers': 207,
#               'gravatar': 'https://secure.gravatar.com/avatar/21f4971707a00270b92e2ae791d5633d?s=140&amp;d=https://a248.e.akamai.net/assets.github.com%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#               'language': 'JavaScript',
#               'location': 'The Netherlands',
#               'repositories': 59,
# ...
